# %%
# !pip install neo4j
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: neo4j in /home/vashinav/.local/lib/python3.12/site-packages (5.25.0)
# Requirement already satisfied: pytz in /home/vashinav/anaconda3/lib/python3.12/site-packages (from neo4j) (2024.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/vashinav/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/vashinav/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vashinav/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vashinav/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vashinav/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/vashinav/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import requests
import json
from neo4j import GraphDatabase

# %%
url = 'https://stapi.co/api/v1/rest/episode/search'

params = {
    'pageSize': 50 ,
    'pageNumber': 1
}

episodes = pd.DataFrame()
response = requests.get(url, params=params)
totalPages = int(response.json()['page']['totalPages'])

for i in range(1, int(totalPages)):
    params['pageNumber'] = i
    response = requests.get(url, params=params)
    epis = pd.json_normalize(response.json(), 'episodes')
    epis = epis[epis['series.uid'] == 'SEMA0000073238']
    epis = epis ['uid']
    # print(epis)
    episodes = pd.concat([episodes, epis])

# %%
url = 'https://stapi.co/api/v1/rest/episode'
char_params = {}
char_ids = {'CHMA0000278202',}

for uid in episodes['uid']:
    char_params['uid'] = uid
    response = requests.get(url, params=char_params)
    characters = pd.json_normalize(response.json())
    characters = characters['episode.characters'][0]
    for character in characters:
        char_ids.add(character['uid'])

# %%
characters = pd.DataFrame()
url = 'https://stapi.co/api/v1/rest/character/'
for uid in char_ids:
    char_params['uid'] = uid
    response = requests.get(url, params=char_params)
    characF = pd.json_normalize(response.json())
    characF = characF[['character.uid', 'character.name', 'character.gender', 'character.episodes', 'character.titles', 'character.organizations']]
    characters = pd.concat([characters, characF])
# Out:
#      character.uid   character.name character.gender  \
# 0   CHMA0000024400            Darok                M
# 0   CHMA0000064944       Fallit Kot             None
# 0   CHMA0000107784           Gowron                M
# 0   CHMA0000011970      Yolad Belar                M
# 0   CHMA0000024987            Lonar             None
# ..             ...              ...              ...
# 0   CHMA0000047636            Vayna             None
# 0   CHMA0000021878             Fala             None
# 0   CHMA0000003725  Lewis Zimmerman                M
# 0   CHMA0000086442       The Albino                M
# 0   CHMA0000011895          Lasaran             None
#
#                                    character.episodes  \
# 0   [{'uid': 'EPMA0000000991', 'title': 'Once More...
# 0   [{'uid': 'EPMA0000000865', 'title': 'Melora', ...
# 0   [{'uid': 'EPMA0000000888', 'title': 'The House...
# 0   [{'uid': 'EPMA0000000889', 'title': 'Equilibri...
# 0   [{'uid': 'EPMA0000001009', 'title': 'The Dogs ...
# ..                                                ...
# 0   [{'uid': 'EPMA0000000869', 'title': 'Sanctuary...
# 0   [{'uid': 'EPMA0000000993', 'title': 'Covenant'...
# 0   [{'uid': 'EPMA0000001475', 'title': 'Projectio...
# 0   [{'uid': 'EPMA0000000878', 'title': 'Blood Oat...
# 0   [{'uid': 'EPMA0000000976', 'title': 'Change of...
#
#                                      character.titles  \
# 0                                                  []
# 0                                                  []
# 0   [{'uid': 'TIMA0000001276', 'name': 'Chancellor...
# 0                                                  []
# 0                                                  []
# ..                                                ...
# 0                                                  []
# 0   [{'uid': 'TIMA0000006129', 'name': 'Vedek', 'm...
# 0                                                  []
# 0                                                  []
# 0   [{'uid': 'TIMA0000226608', 'name': 'Glinn', 'm...
#
#                               character.organizations
# 0   [{'uid': 'ORMA0000083796', 'name': 'Klingon Em...
# 0                                                  []
# 0   [{'uid': 'ORMA0000083796', 'name': 'Klingon Em...
# 0                                                  []
# 0                                                  []
# ..                                                ...
# 0                                                  []
# 0   [{'uid': 'ORMA0000006128', 'name': 'Vedek Asse...
# 0   [{'uid': 'ORMA0000102839', 'name': 'United Fed...
# 0                                                  []
# 0   [{'uid': 'ORMA0000000285', 'name': 'Cardassian...
#
# [619 rows x 6 columns]

# %%
characters_relations = pd.DataFrame()
url = 'https://stapi.co/api/v1/rest/character/'
for uid in char_ids:
    char_params['uid'] = uid
    response = requests.get(url, params=char_params)
    characF = pd.json_normalize(response.json())
    characF = characF[['character.uid', 'character.characterRelations']]
    characters_relations = pd.concat([characters_relations, characF])
characters_relations
# Out:
#      character.uid                       character.characterRelations
# 0   CHMA0000028981                                                 []
# 0   CHMA0000048651                                                 []
# 0   CHMA0000011515                                                 []
# 0   CHMA0000016596                                                 []
# 0   CHMA0000276812                                                 []
# ..             ...                                                ...
# 0   CHMA0000029461                                                 []
# 0   CHMA0000128914  [{'type': 'Spouse', 'source': {'uid': 'CHMA000...
# 0   CHMA0000012788                                                 []
# 0   CHMA0000023300                                                 []
# 0   CHMA0000024339  [{'type': 'Paternal ancestor', 'source': {'uid...
#
# [619 rows x 2 columns]

# %%
URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "password")

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    driver.verify_connectivity()
    with driver.session(database="neo4j") as session:
        for index, row in characters.iterrows():
            charac_query = session.run("CREATE (:Character{uid: $uid, name: $name, gender: $gender})", uid = row['character.uid'], name = row['character.name'], gender = row['character.gender'], database = 'neo4j')
            for episode in row['character.episodes']:
                char_relations = session.run("MATCH (c:Character {uid: $uid}) MATCH(e:Episode {uid: $e_uid}) CREATE (c)-[:APPEARS_IN]->(e)", uid = row['character.uid'], e_uid = episode['uid'])
            for title in row['character.titles']:
                char_titles = session.run("MATCH (c:Character {uid: $uid}) MERGE (t:Title{uid: $t_uid, name: $t_name}) MERGE (c)-[:Title]->(t)", uid = row['character.uid'], t_uid = title['uid'], t_name = title['name'])
            for organization in row['character.organizations']:
                charac_oraganization = session.run("MATCH (c:Character {uid: $uid}) MERGE (o:organization{uid: $o_uid, name:$o_name}) MERGE (c)-[:PART_OF]->(o)", uid = row['character.uid'], o_uid = organization['uid'], o_name = organization['name'])
# Out:
# {'uid': 'TIMA0000001276', 'name': 'Chancellor of the Klingon High Council', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000004731', 'name': 'Grand Nagus', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226606', 'name': 'Legate', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000017083', 'name': 'Lieutenant general', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005009', 'name': 'Constable', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006142', 'name': 'Ranjen', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001725', 'name': 'Colonel', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000014743', 'name': 'Thot', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000105985', 'name': 'Supervisor', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000049219', 'name': 'Admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064866', 'name': 'Lieutenant commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001723', 'name': 'General', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001294', 'name': 'Commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000008563', 'name': 'Vice admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001960', 'name': 'Fleet admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064866', 'name': 'Lieutenant commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001971', 'name': 'Lieutenant junior grade', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000017109', 'name': 'Chief petty officer', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000221679', 'name': 'Acting', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000017109', 'name': 'Chief petty officer', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000011516', 'name': 'Rear admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000021401', 'name': 'Professor', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000008563', 'name': 'Vice admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001723', 'name': 'General', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001723', 'name': 'General', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000015298', 'name': 'Minister', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000021401', 'name': 'Professor', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000021401', 'name': 'Professor', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001294', 'name': 'Commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000204792', 'name': 'Head of state', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226606', 'name': 'Legate', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000011516', 'name': 'Rear admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001294', 'name': 'Commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226606', 'name': 'Legate', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000008911', 'name': 'Hetman', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000008563', 'name': 'Vice admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000039986', 'name': 'Sub-commander', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001725', 'name': 'Colonel', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001971', 'name': 'Lieutenant junior grade', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001723', 'name': 'General', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000004699', 'name': 'Praetor', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000049219', 'name': 'Admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064866', 'name': 'Lieutenant commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000017109', 'name': 'Chief petty officer', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226606', 'name': 'Legate', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000014743', 'name': 'Thot', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000004731', 'name': 'Grand Nagus', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064866', 'name': 'Lieutenant commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000011516', 'name': 'Rear admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000010155', 'name': 'Dahar master', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226606', 'name': 'Legate', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000008563', 'name': 'Vice admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000010155', 'name': 'Dahar master', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001971', 'name': 'Lieutenant junior grade', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000037475', 'name': 'Tetrarch', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226608', 'name': 'Glinn', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000017024', 'name': 'Petty officer', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000049219', 'name': 'Admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000206119', 'name': 'Engineer', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000003802', 'name': 'Ensign', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000010155', 'name': 'Dahar master', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000005212', 'name': 'Crewman', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001971', 'name': 'Lieutenant junior grade', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000009039', 'name': 'Regent', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': True}
# {'uid': 'TIMA0000013602', 'name': 'Prime minister', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001294', 'name': 'Commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006141', 'name': 'Prylar', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006142', 'name': 'Ranjen', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001276', 'name': 'Chancellor of the Klingon High Council', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001723', 'name': 'General', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001971', 'name': 'Lieutenant junior grade', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001723', 'name': 'General', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001725', 'name': 'Colonel', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000004731', 'name': 'Grand Nagus', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064866', 'name': 'Lieutenant commander', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000011516', 'name': 'Rear admiral', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000058726', 'name': 'Field commission', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000058726', 'name': 'Field commission', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000064875', 'name': 'Captain', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226607', 'name': 'Gul', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000001719', 'name': 'Lieutenant', 'militaryRank': True, 'fleetRank': True, 'religiousTitle': False, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000006129', 'name': 'Vedek', 'militaryRank': False, 'fleetRank': False, 'religiousTitle': True, 'position': False, 'mirror': False}
# {'uid': 'TIMA0000226608', 'name': 'Glinn', 'militaryRank': True, 'fleetRank': False, 'religiousTitle': False, 'position': False, 'mirror': False}

# %%
characters_relations[characters_relations['character.uid'] == 'CHMA0000128914']
# Out:
#     character.uid                       character.characterRelations
# 0  CHMA0000128914  [{'type': 'Spouse', 'source': {'uid': 'CHMA000...

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    driver.verify_connectivity()
    with driver.session(database='neo4j') as session:
        for index, row in characters_relations.iterrows():
                for relation in row['character.characterRelations']:
                    relations_query = "MERGE (s:Character{uid: $sourceUid, name: $sourceName})-[:"+ relation['type'].replace(' ', '_').replace("-", "_") +"]->(t:Character{uid: $targetUid, name:$targetName})"
                    # print(relations_query)
                    relations_result = session.run(relations_query, sourceUid = relation['source']['uid'], sourceName = relation['source']['name'], type = relation['type'], targetUid = relation['target']['uid'], targetName = relation['target']['name'])
                    break
# Out:
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# Cell In[59], line 8
#       6 relations_query = "MERGE (s:Character{uid: $sourceUid, name: $sourceName})-[:"+ relation['type'].replace(' ', '_') +"]->(t:Character{uid: $targetUid, name:$targetName})"
#       7 # print(relations_query)
# ----> 8 relations_result = session.run(relations_query, sourceUid = relation['source']['uid'], sourceName = relation['source']['name'], type = relation['type'], targetUid = relation['target']['uid'], targetName = relation['target']['name'])
#       9 break
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/work/session.py:320, in Session.run(self, query, parameters, **kwargs)
#     318 bookmarks = self._get_bookmarks()
#     319 parameters = dict(parameters or {}, **kwargs)
# --> 320 self._auto_result._run(
#     321     query,
#     322     parameters,
#     323     self._config.database,
#     324     self._config.impersonated_user,
#     325     self._config.default_access_mode,
#     326     bookmarks,
#     327     self._config.notifications_min_severity,
#     328     self._config.notifications_disabled_classifications,
#     329 )
#     331 return self._auto_result
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/work/result.py:231, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     229 self._pull()
#     230 self._connection.send_all()
# --> 231 self._attach()
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/work/result.py:425, in Result._attach(self)
#     423 if self._exhausted is False:
#     424     while self._attached is False:
# --> 425         self._connection.fetch_message()
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:181, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     179 def inner(*args, **kwargs):
#     180     try:
# --> 181         func(*args, **kwargs)
#     182     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     183         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:977, in Bolt.fetch_message(self)
#     973 # Receive exactly one message
#     974 tag, fields = self.inbox.pop(
#     975     hydration_hooks=self.responses[0].hydration_hooks
#     976 )
# --> 977 res = self._process_message(tag, fields)
#     978 self.idle_since = monotonic()
#     979 return res
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_bolt5.py:466, in Bolt5x0._process_message(self, tag, fields)
#     464 self._server_state_manager.state = self.bolt_states.FAILED
#     465 try:
# --> 466     response.on_failure(summary_metadata or {})
#     467 except (ServiceUnavailable, DatabaseUnavailable):
#     468     if self.pool:
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:251, in Response.on_failure(self, metadata)
#     249 handler = self.handlers.get("on_summary")
#     250 Util.callback(handler)
# --> 251 raise Neo4jError.hydrate(**metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '-': expected a parameter, '&', '*', ':', 'WHERE', ']', '{' or '|' (line 1, column 65 (offset: 64))
# "MERGE (s:Character{uid: $sourceUid, name: $sourceName})-[:Son_in-law]->(t:Character{uid: $targetUid, name:$targetName})"
#                                                                  ^}
